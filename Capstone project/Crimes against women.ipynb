# %% [markdown]
# # **EDA on Crimes against Women**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime 
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Data and Metadata

# %%
df1=pd.read_csv('42_District_wise_crimes_committed_against_women_2001_2012.csv')
df1.shape
# Out:
# (9017, 10)

# %%
df2=pd.read_csv('42_District_wise_crimes_committed_against_women_2013.csv')
df2.shape
# Out:
# (823, 10)

# %%
df=pd.concat([df1,df2])
df.shape
# Out:
# (9840, 10)

# %%
df.head()
# Out:
#          STATE/UT       DISTRICT  Year  Rape  Kidnapping and Abduction  \
# 0  ANDHRA PRADESH       ADILABAD  2001    50                        30
# 1  ANDHRA PRADESH      ANANTAPUR  2001    23                        30
# 2  ANDHRA PRADESH       CHITTOOR  2001    27                        34
# 3  ANDHRA PRADESH       CUDDAPAH  2001    20                        20
# 4  ANDHRA PRADESH  EAST GODAVARI  2001    23                        26
#
#    Dowry Deaths  Assault on women with intent to outrage her modesty  \
# 0            16                                                149
# 1             7                                                118
# 2            14                                                112
# 3            17                                                126
# 4            12                                                109
#
#    Insult to modesty of Women  Cruelty by Husband or his Relatives  \
# 0                          34                                  175
# 1                          24                                  154
# 2                          83                                  186
# 3                          38                                   57
# 4                          58                                  247
#
#    Importation of Girls
# 0                     0
# 1                     0
# 2                     0
# 3                     0
# 4                     0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9840 entries, 0 to 822
# Data columns (total 10 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   STATE/UT                                             9840 non-null   object
#  1   DISTRICT                                             9840 non-null   object
#  2   Year                                                 9840 non-null   int64
#  3   Rape                                                 9840 non-null   int64
#  4   Kidnapping and Abduction                             9840 non-null   int64
#  5   Dowry Deaths                                         9840 non-null   int64
#  6   Assault on women with intent to outrage her modesty  9840 non-null   int64
#  7   Insult to modesty of Women                           9840 non-null   int64
#  8   Cruelty by Husband or his Relatives                  9840 non-null   int64
#  9   Importation of Girls                                 9840 non-null   int64
# dtypes: int64(8), object(2)
# memory usage: 845.6+ KB

# %%
df.describe()
# Out:
#               Year         Rape  Kidnapping and Abduction  Dowry Deaths  \
# count  9840.000000  9840.000000               9840.000000   9840.000000
# mean   2007.161890    55.456098                 64.184553     20.179878
# std       3.755581   201.690457                278.536450     97.446611
# min    2001.000000     0.000000                  0.000000      0.000000
# 25%    2004.000000     8.000000                  6.000000      1.000000
# 50%    2007.000000    21.000000                 19.000000      5.000000
# 75%    2010.000000    43.000000                 46.000000     16.000000
# max    2013.000000  4335.000000               9737.000000   2335.000000
#
#        Assault on women with intent to outrage her modesty  \
# count                                        9840.000000
# mean                                          106.482520
# std                                           423.729483
# min                                             0.000000
# 25%                                            10.000000
# 50%                                            33.000000
# 75%                                            80.000000
# max                                          8252.000000
#
#        Insult to modesty of Women  Cruelty by Husband or his Relatives  \
# count                 9840.000000                          9840.000000
# mean                    27.772967                           202.046138
# std                    170.367098                           869.325453
# min                      0.000000                             0.000000
# 25%                      0.000000                            11.000000
# 50%                      2.000000                            49.000000
# 75%                     13.000000                           139.250000
# max                   4970.000000                         19865.000000
#
#        Importation of Girls
# count           9840.000000
# mean               0.187602
# std                2.319261
# min                0.000000
# 25%                0.000000
# 50%                0.000000
# 75%                0.000000
# max               83.000000

# %%
df.isnull().sum()
# Out:
# STATE/UT                                               0
# DISTRICT                                               0
# Year                                                   0
# Rape                                                   0
# Kidnapping and Abduction                               0
# Dowry Deaths                                           0
# Assault on women with intent to outrage her modesty    0
# Insult to modesty of Women                             0
# Cruelty by Husband or his Relatives                    0
# Importation of Girls                                   0
# dtype: int64

# %%
df.nunique()
# Out:
# STATE/UT                                                70
# DISTRICT                                               828
# Year                                                    13
# Rape                                                   449
# Kidnapping and Abduction                               507
# Dowry Deaths                                           270
# Assault on women with intent to outrage her modesty    599
# Insult to modesty of Women                             365
# Cruelty by Husband or his Relatives                    912
# Importation of Girls                                    37
# dtype: int64

# %%
list(df["STATE/UT"].unique())
# Out:
# ['ANDHRA PRADESH',
#  'ARUNACHAL PRADESH',
#  'ASSAM',
#  'BIHAR',
#  'CHHATTISGARH',
#  'GOA',
#  'GUJARAT',
#  'HARYANA',
#  'HIMACHAL PRADESH',
#  'JAMMU & KASHMIR',
#  'JHARKHAND',
#  'KARNATAKA',
#  'KERALA',
#  'MADHYA PRADESH',
#  'MAHARASHTRA',
#  'MANIPUR',
#  'MEGHALAYA',
#  'MIZORAM',
#  'NAGALAND',
#  'ODISHA',
#  'PUNJAB',
#  'RAJASTHAN',
#  'SIKKIM',
#  'TAMIL NADU',
#  'TRIPURA',
#  'UTTAR PRADESH',
#  'UTTARAKHAND',
#  'WEST BENGAL',
#  'A & N ISLANDS',
#  'CHANDIGARH',
#  'D & N HAVELI',
#  'DAMAN & DIU',
#  'DELHI',
#  'LAKSHADWEEP',
#  'PUDUCHERRY',
#  'Andhra Pradesh',
#  'Arunachal Pradesh',
#  'Assam',
#  'Bihar',
#  'Chhattisgarh',
#  'Goa',
#  'Gujarat',
#  'Haryana',
#  'Himachal Pradesh',
#  'Jammu & Kashmir',
#  'Jharkhand',
#  'Karnataka',
#  'Kerala',
#  'Madhya Pradesh',
#  'Maharashtra',
#  'Manipur',
#  'Meghalaya',
#  'Mizoram',
#  'Nagaland',
#  'Odisha',
#  'Punjab',
#  'Rajasthan',
#  'Sikkim',
#  'Tamil Nadu',
#  'Tripura',
#  'Uttar Pradesh',
#  'Uttarakhand',
#  'West Bengal',
#  'A&N Islands',
#  'Chandigarh',
#  'D&N Haveli',
#  'Daman & Diu',
#  'Delhi UT',
#  'Lakshadweep',
#  'Puducherry']

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Data Cleaning on STATE/UT Column

# %%
print(list(df["STATE/UT"].unique()))
print(len(list(df["STATE/UT"].unique())))
# Out:
# ['ANDHRA PRADESH', 'ARUNACHAL PRADESH', 'ASSAM', 'BIHAR', 'CHHATTISGARH', 'GOA', 'GUJARAT', 'HARYANA', 'HIMACHAL PRADESH', 'JAMMU & KASHMIR', 'JHARKHAND', 'KARNATAKA', 'KERALA', 'MADHYA PRADESH', 'MAHARASHTRA', 'MANIPUR', 'MEGHALAYA', 'MIZORAM', 'NAGALAND', 'ODISHA', 'PUNJAB', 'RAJASTHAN', 'SIKKIM', 'TAMIL NADU', 'TRIPURA', 'UTTAR PRADESH', 'UTTARAKHAND', 'WEST BENGAL', 'A & N ISLANDS', 'CHANDIGARH', 'D & N HAVELI', 'DAMAN & DIU', 'DELHI', 'LAKSHADWEEP', 'PUDUCHERRY', 'Andhra Pradesh', 'Arunachal Pradesh', 'Assam', 'Bihar', 'Chhattisgarh', 'Goa', 'Gujarat', 'Haryana', 'Himachal Pradesh', 'Jammu & Kashmir', 'Jharkhand', 'Karnataka', 'Kerala', 'Madhya Pradesh', 'Maharashtra', 'Manipur', 'Meghalaya', 'Mizoram', 'Nagaland', 'Odisha', 'Punjab', 'Rajasthan', 'Sikkim', 'Tamil Nadu', 'Tripura', 'Uttar Pradesh', 'Uttarakhand', 'West Bengal', 'A&N Islands', 'Chandigarh', 'D&N Haveli', 'Daman & Diu', 'Delhi UT', 'Lakshadweep', 'Puducherry']
# 70

# %% [markdown]
# In India we have only 36 States/UT but as per the data it has 72 States/UT. This is because some of the states/UT have been entered both in capital and small letters. Since the data is case sensitive, we get a total of 72 unique states/UT, while there are only 36. To clear this issue we converted all to a lower case. FUrthermore, all spacing issues were also resolved in order to bring down the number of unique states/UT to 36.

# %%
df.replace({'A&N Islands':'A & N Islands','D&N Haveli':'D & N HAVELI','Delhi UT':'DELHI'},inplace=True)

# %%
len(list(df["STATE/UT"].unique()))
# Out:
# 68

# %%
df["STATE/UT"]=df["STATE/UT"].str.casefold()

# %%
len(list(df["STATE/UT"].unique()))
# Out:
# 35

# %%
df["DISTRICT"].value_counts()
# Out:
# TOTAL              408
# G.R.P.              49
# SOUTH               41
# NORTH               41
# WEST                39
#                   ...
# MIDNAPUR             1
# G.R.P. AJMER         1
# G.R.P. JODHPUR       1
# A and N ISLANDS      1
# METRO RAIL           1
# Name: DISTRICT, Length: 828, dtype: int64

# %% [markdown]
# ### Data Cleaning on DISTRICT
#   Initially we converted all the entries to lower case, and then obtained the unique list of District, while inspecting found that it has entries like "total", "zz total", "total district(s)", "delhi ut total" this doesn't look like an district name so while investigating it seems to be an total value of that state on each crime.
#   If it present in the data it will mess up the data by increasing the No. of cases in each category so, found the indexes of that total and removed from the dataset

# %%
df["DISTRICT"]=df["DISTRICT"].str.lower()

# %%
df=df.drop(list(df[df["DISTRICT"]=="total"].index))

# %%
len(list(df[df["DISTRICT"]=="zz total"].index))
# Out:
# 35

# %%
len(list(df[df["DISTRICT"]=="total district(s)"].index))
# Out:
# 0

# %%
len(list(df[df["DISTRICT"]=="delhi ut total"].index))
# Out:
# 12

# %%
df=df.drop(list(df[df["DISTRICT"]=="zz total"].index))

# %%
df=df.drop(list(df[df["DISTRICT"]=="total district(s)"].index))

# %%
df=df.drop(list(df[df["DISTRICT"]=="delhi ut total"].index))

# %%
df["DISTRICT"].value_counts()
# Out:
# g.r.p.             47
# south              41
# north              41
# west               39
# railways           37
#                    ..
# midnapur            1
# a and n islands     1
# viluppuram          1
# bemetara            1
# metro rail          1
# Name: DISTRICT, Length: 824, dtype: int64

# %%
df["DISTRICT"].unique()
# Out:
# array(['adilabad', 'anantapur', 'chittoor', 'cuddapah', 'east godavari',
#        'guntakal rly.', 'guntur', 'hyderabad city', 'karimnagar',
#        'khammam', 'krishna', 'kurnool', 'mahaboobnagar', 'medak',
#        'nalgonda', 'nellore', 'nizamabad', 'prakasham', 'ranga reddy',
#        'secunderabad rly.', 'srikakulam', 'vijayawada', 'vijayawada rly.',
#        'visakha rural', 'visakhapatnam', 'vizianagaram', 'warangal',
#        'west godavari', 'changlang', 'dibang valley', 'kameng east',
#        'kameng west', 'papum pare', 'siang east', 'siang upper',
#        'siang west', 'subansiri lower', 'subansiri upper', 'tawang',
#        'tirap', 'barpeta', 'bongaigaon', 'c.i.d.', 'cachar', 'darrang',
#        'dhemaji', 'dhubri', 'dibrugarh', 'g.r.p.', 'golaghat',
#        'guwahati city', 'hailakandi', 'jorhat', 'kamrup', 'karbi anglong',
#        'karimganj', 'kokrajhar', 'lakhimpur', 'morigaon', 'n.c.hills',
#        'nagaon', 'nalbari', 'r.p.o.', 'sibsagar', 'sonitpur', 'tinsukia',
#        'araria', 'arwal', 'aurangabad', 'bagaha', 'banka', 'begusarai',
#        'bettiah', 'bhabhua', 'bhagalpur', 'bhojpur', 'buxar', 'darbhanga',
#        'gaya', 'gopalganj', 'jamalpur rly.', 'jehanabad', 'katihar',
#        'katihar rly.', 'khagaria', 'kishanganj', 'lakhisarai',
#        'madhepura', 'madhubani', 'motihari', 'munger', 'muzaffarpur',
#        'muzaffarpur rly.', 'nalanda', 'naugachia', 'nawadah', 'patna',
#        'patna rly.', 'purnea', 'rohtas', 'saharsa', 'samastipur', 'saran',
#        'sheikhpura', 'sheohar', 'sitamarhi', 'siwan', 'supaul',
#        'vaishali', 'balrampur', 'bilaspur', 'bizapur', 'dantewara',
#        'dhamtari', 'durg', 'grp raipur', 'jagdalpur', 'janjgir',
#        'jashpur', 'kanker', 'kawardha', 'korba', 'koriya', 'mahasamund',
#        'raipur', 'rajnandgaon', 'sarguja', 'north goa', 'south goa',
#        'ahmedabad commr.', 'ahmedabad rural', 'ahwa-dang', 'amreli',
#        'anand', 'bharuch', 'bhavnagar', 'dahod', 'gandhinagar',
#        'himatnagar', 'jamnagar', 'junagadh', 'kheda north', 'kutch',
#        'mehsana', 'narmada', 'navsari', 'palanpur', 'panchmahal', 'patan',
#        'porbandar', 'rajkot rural', 'surat commr.', 'surendranagar',
#        'vadodara commr.', 'vadodara rural', 'valsad', 'w.rly', 'ambala',
#        'bhiwani', 'faridabad', 'fatehabad', 'grp', 'gurgaon', 'hissar',
#        'jhajjar', 'jind', 'kaithal', 'karnal', 'kurukshetra',
#        'mahendragarh', 'panchkula', 'panipat', 'rewari', 'rohtak',
#        'sirsa', 'sonipat', 'yamunanagar', 'chamba', 'hamirpur', 'kangra',
#        'kinnaur', 'kullu', 'mandi', 'shimla', 'sirmaur', 'solan', 'una',
#        'anantnag', 'awantipora', 'baramulla', 'border', 'budgam',
#        'crime jammu', 'crime srinagar', 'doda', 'ganderbal', 'jammu',
#        'kargil', 'kathua', 'kulgam', 'kupwara', 'leh', 'poonch',
#        'pulwama', 'railways', 'ramban', 'reasi', 'srinagar', 'udhampur',
#        'bokaro', 'chaibasa', 'chatra', 'deoghar', 'dhanbad',
#        'dhanbad rly.', 'dumka', 'garhwa', 'giridih', 'godda',
#        'hazaribagh', 'jamshedpur', 'jamshedpur rly.', 'jamtara',
#        'koderma', 'latehar', 'lohardagga', 'pakur', 'palamu', 'ranchi',
#        'sahebganj', 'saraikela', 'simdega', 'bagalkot',
#        'bangalore commr.', 'bangalore rural', 'belgaum', 'bellary',
#        'bidar', 'bijapur', 'chamarajnagar', 'chickmagalur', 'chitradurga',
#        'dakshin kannada', 'davanagere', 'dharwad commr.', 'dharwad rural',
#        'gadag', 'gulbarga', 'haveri', 'k.g.f.', 'kodagu', 'kolar',
#        'koppal', 'mandya', 'mysore commr.', 'mysore rural', 'raichur',
#        'shimoga', 'tumkur', 'udupi', 'uttar kannada', 'alapuzha', 'cbcid',
#        'ernakulam', 'idukki', 'kannur', 'kasargod', 'kollam', 'kottayam',
#        'kozhikode', 'malappuram', 'palakkad', 'thrissur', 'trivandrum',
#        'wayanadu', 'balaghat', 'barwani', 'betul', 'bhind', 'bhopal',
#        'bhopal rly.', 'chhatarpur', 'chhindwara', 'damoh', 'datiya',
#        'dewas', 'dhar', 'dindori', 'guna', 'gwalior', 'harda',
#        'hoshangabad', 'indore', 'indore rly.', 'jabalpur',
#        'jabalpur rly.', 'jhabua', 'katni', 'khandwa', 'khargon', 'mandla',
#        'mandsaur', 'morena', 'narsinghpur', 'neemuch', 'raisen',
#        'rajgarh', 'ratlam', 'rewa', 'sagar', 'satna', 'seoni', 'shahdol',
#        'shajapur', 'sheopur', 'shivpuri', 'sidhi', 'sihore', 'tikamgarh',
#        'ujjain', 'umariya', 'vidisha', 'ahmednagar', 'akola',
#        'amravati rural', 'aurangabad commr.', 'aurangabad rural', 'beed',
#        'bhandara', 'buldhana', 'chandrapur', 'dhule', 'gadchiroli',
#        'gondia', 'hingoli', 'jalgaon', 'jalna', 'kolhapur', 'latur',
#        'mumbai', 'mumbai rly.', 'nagpur commr.', 'nagpur rly.',
#        'nagpur rural', 'nanded', 'nandurbar', 'nasik commr.',
#        'nasik rural', 'navi mumbai', 'osmanabad', 'parbhani',
#        'pune commr.', 'pune rly.', 'pune rural', 'raigad', 'ratnagiri',
#        'sangli', 'satara', 'sindhudurg', 'solapur commr.',
#        'solapur rural', 'thane commr.', 'thane rural', 'wardha', 'washim',
#        'yavatmal', 'bishnupur', 'chandel', 'churachandpur',
#        'imphal(east)', 'imphal(west)', 'senapati', 'tamenglong',
#        'thoubal', 'ukhrul', 'garo hills east', 'garo hills west',
#        'jaintia hills', 'khasi hills east', 'khasi hills west', 'ri-bhoi',
#        'aizawl', 'champhai', 'kolasib', 'lawngtlai', 'lunglei', 'mamit',
#        'saiha', 'serchhip', 'dimapur', 'kiphire', 'kohima', 'mokokchung',
#        'mon', 'peren', 'phek', 'tuensang', 'wokha', 'zunheboto', 'angul',
#        'balasore', 'baragarh', 'berhampur', 'bhadrak', 'bolangir',
#        'boudh', 'cuttack', 'deogarh', 'dhenkanal', 'gajapati', 'ganjam',
#        'jagatsinghpur', 'jajpur', 'jharsuguda', 'kalahandi', 'kandhamal',
#        'kendrapara', 'keonjhar', 'koraput', 'malkangir', 'mayurbhanj',
#        'nayagarh', 'nowrangpur', 'nuapada', 'puri', 'rayagada',
#        'rourkela', 'sambalpur', 'srp(cuttack)', 'srp(rourkela)',
#        'sundargarh', 'amritsar', 'barnala', 'batala', 'bhatinda',
#        'faridkot', 'fatehgarh sahib', 'ferozepur', 'gurdaspur',
#        'hoshiarpur', 'jagraon', 'jalandhar', 'kapurthala', 'khanna',
#        'ludhiana', 'majitha', 'mansa', 'moga', 'nawan shahr', 'patiala',
#        'ropar', 'sangrur', 'tarn taran', 'ajmer', 'alwar', 'banswara',
#        'baran', 'barmer', 'bhilwara', 'bikaner', 'bundi', 'chittorgarh',
#        'churu', 'dausa', 'dholpur', 'dungarpur', 'ganganagar',
#        'hanumangarh', 'jaipur', 'jaisalmer', 'jalore', 'jhalawar',
#        'jhunjhunu', 'jodhpur', 'karauli', 'kota', 'nagaur', 'pali',
#        'rajsamand', 'sawai madhopur', 'sikar', 'sirohi', 'tonk',
#        'udaipur', 'east', 'north', 'south', 'west', 'ariyalur', 'chengai',
#        'chennai', 'coimbatore rural', 'coimbatore urban', 'cuddalore',
#        'dharmapuri', 'dindigul', 'erode', 'kanchipuram', 'kanyakumari',
#        'karur', 'madurai rural', 'madurai urban', 'nagapattinam',
#        'namakkal', 'nilgiris', 'perambalur', 'pudukottai',
#        'ramnathapuram', 'salem rural', 'salem urban', 'sivagangai',
#        'thanjavur', 'theni', 'thirunelveli rural', 'thirunelveli urban',
#        'thiruvallur', 'thiruvannamalai', 'thiruvarur', 'thoothugudi',
#        'trichy rural', 'trichy urban', 'vellore', 'villupuram',
#        'virudhunagar', 'dhalai', 'agra', 'aligarh', 'allahabad',
#        'ambedkar nagar', 'auraiya', 'azamgarh', 'badaun', 'baghpat',
#        'bahraich', 'ballia', 'banda', 'barabanki', 'bareilly', 'basti',
#        'bijnor', 'bulandshahar', 'chandoli', 'chitrakoot dham', 'deoria',
#        'etah', 'etawah', 'faizabad', 'fatehgarh', 'fatehpur', 'firozabad',
#        'gautambudh nagar', 'ghaziabad', 'ghazipur', 'gonda', 'gorakhpur',
#        'hardoi', 'hathras', 'j.p.nagar', 'jalaun', 'jhansi', 'kannauj',
#        'kanpur dehat', 'kanpur nagar', 'kaushambi', 'khiri',
#        'kushi nagar', 'lalitpur', 'lucknow', 'maharajganj', 'mahoba',
#        'mainpuri', 'mathura', 'mau', 'meerut', 'mirzapur', 'moradabad',
#        'muzaffarnagar', 'pilibhit', 'pratapgarh', 'raibareilly', 'rampur',
#        'saharanpur', 'sant kabirnagar', 'shahjahanpur', 'shrawasti',
#        'sidharthnagar', 'sitapur', 'sonbhadra', 'st.ravidasnagar',
#        'sultanpur', 'unnao', 'varanasi', 'almora', 'bageshwar', 'chamoli',
#        'champawat', 'dehradun', 'nainital', 'pauri garhwal',
#        'pithoragarh', 'rudra prayag', 'tehri garhwal', 'udhamsingh nagar',
#        'uttarkashi', '24 parganas north', 'asansol', 'bankura', 'birbhum',
#        'burdwan', 'coochbehar', 'dakshin dinajpur', 'darjeeling',
#        'hooghly', 'howrah', 'howrah city', 'howrah g.r.p.', 'jalpaiguri',
#        'kolkata', 'malda', 'midnapur', 'murshidabad', 'nadia', 'purulia',
#        'sealdah g.r.p.', 'siliguri g.r.p.', 'uttar dinajpur', 'andaman',
#        'nicobar', 'chandigarh', 'd and n haveli', 'daman', 'diu',
#        'central', 'g.r.p.(rly)', 'i.g.i. airport', 'new delhi',
#        'north east', 'north west', 's.t.f.', 'south west', 'lakshadweep',
#        'pondicherry', 'lohit', 'goalpara', 'jamui', 'kabirdham',
#        'raigarh', 'rajkot commr.', 'surat rural', 'lahaul-spiti',
#        'handwara', 'rajouri', 'gumla', 'hassan', 'pathanamthitta',
#        'panna', 'amravati commr.', 'garo hills south', 'khurda',
#        'sonepur', 'g.r.p', 'muktsar', 'bharatpur', 'chennai rly.',
#        'trichy rly.', 'jaunpur', 'haridwar', '24 parganas south',
#        'kharagpur g.r.p.', 'paschim midnapur', 'purab midnapur',
#        'spl cell', 'cyberabad', 'k/kumey', 'upper dibang valley',
#        'narayanpur', 'ernakulam commr.', 'ernakulam rural',
#        'kozhikode commr.', 'kozhikode rural', 'trivandrum commr.',
#        'trivandrum rural', 'anuppur', 'ashok nagar', 'burhanpur',
#        'krishnagiri', 'baska', 'chirang', 'udalguri', 'surajpur', 'mewat',
#        'ferozpur', 'viluppuram', 'igi airport', 'north-east',
#        'north-west', 'south-west', 'vijayawada city', 'palwal',
#        'border district', 'mumbai commr.', 'imphal east', 'imphal west',
#        'sas ngr', 'jaipur east', 'jaipur north', 'jaipur rural',
#        'jaipur south', 'jodhpur city', 'jodhpur rural', 'kota city',
#        'kota rural', 'grp(rly)', 'stf', 'karaikal', 'khunti', 'ramgarh',
#        'longleng', 'amritsar rural', 'a and n islands', 'outer', 'tapi',
#        'bandipora', 'kishtwar', 'samba', 'shopian', 'cbpura', 'ramanagar',
#        'alirajpur', 'singrauli', 'cid', 'dcp bbsr', 'dcp ctc',
#        'ludhiana rural', 'sbs nagar', 'chennaisuburban',
#        'kanshiram nagar', 'caw', 'crime branch', 'eow', 'south-east',
#        'puducherry', 'anjaw', 'baddipolicedist', 'railways kmr',
#        'tiruppur', 'guntur urban', 'rajahmundry', 'tirupathi urban',
#        'warangal urban', 'rural', 'cid crime', 'crime kashmir', 'sopore',
#        'yadgiri', 'cp amritsar', 'cp jalandhar', 'cp ludhiana',
#        'jalandhar rural', 'g.r.p. ajmer', 'g.r.p. jodhpur', 'csm nagar',
#        'ramabai nagar', 'gariyaband', 'kutch (east(g))',
#        'kutch (west-bhuj)', 'w.rly ahmedabad', 'w.rly vadodara',
#        'railways jammu', 'railways kashmir', 'mangalore city',
#        'kollam commr.', 'kollam rural', 'thrissur commr.',
#        'thrissur rural', 'fazilka', 'pathankot', 'g.r.p.ajmer',
#        'g.r.p.jodhpur', 'jaipur west', 'bhim nagar', 'panchshil nagar',
#        'prabuddh nagar', 'baksa', 'bieo', 'hamren', 'balod',
#        'baloda bazar', 'bemetara', 'kondagaon', 'mungeli', 'sukma',
#        'ambala rural', 'ambala urban', 'railways katra', 'jodhpur east',
#        'jodhpur west', 'gomati', 'khowai', 'sipahijala', 'unakoti',
#        'bdn cp', 'bkp cp', 'jhargram', 'siliguri_pc', 'car', 'longding',
#        'i&p haryana', 'agar', 'garo hills north', 'jaintia hills east',
#        'jaintia hills west', 'khasi hills south w.', 'spl narcotic',
#        'traffic ps', 'discom', 'amethi', 'amroha', 'hapur', 'kasganj',
#        'sambhal', 'shamli', 'd&n haveli', 'metro rail'], dtype=object)

# %%
df.columns
# Out:
# Index(['STATE/UT', 'DISTRICT', 'Year', 'Rape', 'Kidnapping and Abduction',
#        'Dowry Deaths', 'Assault on women with intent to outrage her modesty',
#        'Insult to modesty of Women', 'Cruelty by Husband or his Relatives',
#        'Importation of Girls'],
#       dtype='object')

# %%
df["Total"]=df["Rape"]+df["Kidnapping and Abduction"]+df["Dowry Deaths"]+df["Assault on women with intent to outrage her modesty"]+df["Insult to modesty of Women"]+df["Cruelty by Husband or his Relatives"]+df["Importation of Girls"]

# %%
df.head()
# Out:
#          STATE/UT       DISTRICT  Year  Rape  Kidnapping and Abduction  \
# 0  andhra pradesh       adilabad  2001    50                        30
# 1  andhra pradesh      anantapur  2001    23                        30
# 2  andhra pradesh       chittoor  2001    27                        34
# 3  andhra pradesh       cuddapah  2001    20                        20
# 4  andhra pradesh  east godavari  2001    23                        26
#
#    Dowry Deaths  Assault on women with intent to outrage her modesty  \
# 0            16                                                149
# 1             7                                                118
# 2            14                                                112
# 3            17                                                126
# 4            12                                                109
#
#    Insult to modesty of Women  Cruelty by Husband or his Relatives  \
# 0                          34                                  175
# 1                          24                                  154
# 2                          83                                  186
# 3                          38                                   57
# 4                          58                                  247
#
#    Importation of Girls  Total
# 0                     0    454
# 1                     0    356
# 2                     0    456
# 3                     0    278
# 4                     0    475

# %%
df.shape
# Out:
# (9312, 11)

# %% [markdown]
# ## Yearly crime rate analysis

# %%
plt.figure(figsize=(12,8))
df.groupby("Year")["Total"].sum().plot.bar()
# Out:
# <AxesSubplot:xlabel='Year'>

# %% [markdown]
# We can see that the crime rate has been steadily increasing as the years pass by.

# %% [markdown]
# ### Percentage Distribution of each Crime based on Year

# %%
df.groupby("Year")["Rape"].sum().plot.pie(autopct='%1.0f%%')
plt.tight_layout()

# %%
df.groupby("Year")["Kidnapping and Abduction"].sum().plot.pie(autopct='%1.0f%%')
plt.tight_layout()

# %%
df.groupby("Year")["Dowry Deaths"].sum().plot.pie(autopct='%1.0f%%')
plt.tight_layout()

# %%
df.groupby("Year")["Assault on women with intent to outrage her modesty"].sum().plot.pie(autopct='%1.0f%%')
plt.tight_layout()

# %%
df.groupby("Year")["Insult to modesty of Women"].sum().plot.pie(autopct='%1.0f%%')
plt.tight_layout()

# %%
df.groupby("Year")["Cruelty by Husband or his Relatives"].sum().plot.pie(autopct='%1.0f%%')
plt.tight_layout()

# %%
df.groupby("Year")["Importation of Girls"].sum().plot.pie(autopct='%1.0f%%')
plt.tight_layout()

# %% [markdown]
# ### Summary
#   All the crime types against women have been summarized as line graphs to visually show the trend as years go by.

# %%
plt.figure(figsize=(20,12))
plt.subplot(2,4,1)
df.groupby("Year")["Rape"].sum().plot(title="Rape")
plt.subplot(2,4,2)
df.groupby("Year")["Kidnapping and Abduction"].sum().plot(title="Kidnapping and Abduction")
plt.subplot(2,4,3)
df.groupby("Year")["Dowry Deaths"].sum().plot(title="Dowry Deaths")
plt.subplot(2,4,6)
df.groupby("Year")["Assault on women with intent to outrage her modesty"].sum().plot(title="Assault on women with intent to outrage her modesty")
plt.subplot(2,4,5)
df.groupby("Year")["Insult to modesty of Women"].sum().plot(title="Insult to modesty of Women")
plt.subplot(2,4,4)
df.groupby("Year")["Cruelty by Husband or his Relatives"].sum().plot(title="Cruelty by Husband or his Relatives")
plt.subplot(2,4,7)
df.groupby("Year")["Importation of Girls"].sum().plot(title="Importation of Girls")
plt.subplot(2,4,8)
df.groupby("Year")["Total"].sum().plot(title="Total No. of Crimes")
# Out:
# <AxesSubplot:title={'center':'Total No. of Crimes'}, xlabel='Year'>

# %%
plt.figure(figsize=(15,7))
df.groupby("Year")["Rape"].sum().plot()
df.groupby("Year")["Kidnapping and Abduction"].sum().plot()
df.groupby("Year")["Dowry Deaths"].sum().plot(label="Dowry Deaths")
df.groupby("Year")["Assault on women with intent to outrage her modesty"].sum().plot()
df.groupby("Year")["Insult to modesty of Women"].sum().plot()
df.groupby("Year")["Cruelty by Husband or his Relatives"].sum().plot()
df.groupby("Year")["Importation of Girls"].sum().plot()
plt.legend()
plt.tight_layout()

# %% [markdown]
# ### Categorical yearly crime rates

# %%
crimes=['Rape','Kidnapping and Abduction','Dowry Deaths',
        'Assault on women with intent to outrage her modesty',
        'Insult to modesty of Women','Cruelty by Husband or his Relatives',
        'Importation of Girls']

df1=pd.DataFrame()
for i in crimes:
    df_c=df.groupby(['Year'])[i].sum()
    df1[i]=df_c
df1
# Out:
#        Rape  Kidnapping and Abduction  Dowry Deaths  \
# Year
# 2001  15587                     14231          6625
# 2002  15996                     14276          6696
# 2003  15847                     13296          6208
# 2004  18233                     15578          7026
# 2005  18359                     15750          6787
# 2006  19348                     17414          7618
# 2007  20737                     20416          8093
# 2008  21467                     22939          8172
# 2009  21397                     25741          8383
# 2010  22172                     29795          8391
# 2011  24206                     35565          8618
# 2012  24923                     38262          8233
# 2013  32278                     49380          7605
#
#       Assault on women with intent to outrage her modesty  \
# Year
# 2001                                              33330
# 2002                                              33571
# 2003                                              32939
# 2004                                              34567
# 2005                                              34175
# 2006                                              36617
# 2007                                              38734
# 2008                                              40413
# 2009                                              38711
# 2010                                              40613
# 2011                                              42968
# 2012                                              45351
# 2013                                              67602
#
#       Insult to modesty of Women  Cruelty by Husband or his Relatives  \
# Year
# 2001                        9616                                47465
# 2002                       10078                                48547
# 2003                       12325                                50703
# 2004                       10001                                58121
# 2005                        9984                                58319
# 2006                        9966                                63128
# 2007                       10950                                75930
# 2008                       12214                                81344
# 2009                       11009                                89546
# 2010                        9961                                94041
# 2011                        8570                                99135
# 2012                        9173                               106527
# 2013                       12267                               112202
#
#       Importation of Girls
# Year
# 2001                   113
# 2002                    72
# 2003                    46
# 2004                    89
# 2005                   149
# 2006                    67
# 2007                    61
# 2008                    67
# 2009                    48
# 2010                    36
# 2011                    80
# 2012                    59
# 2013                    31

# %% [markdown]
# ### Percentage Distribution of crime type

# %%
a=[]
for i in crimes:
  a.append(df1[i].sum())
a.sort()
plt.figure(figsize=(10,15))
plt.pie(a,labels=crimes,autopct='%1.2f%%',colors=['black', 'gold', 'lightskyblue', 'lightcoral','lightpink','lightcyan','lightgreen'])
plt.tight_layout()

# %%
df1.T
# Out:
# Year                                                 2001   2002   2003  \
# Rape                                                15587  15996  15847
# Kidnapping and Abduction                            14231  14276  13296
# Dowry Deaths                                         6625   6696   6208
# Assault on women with intent to outrage her mod...  33330  33571  32939
# Insult to modesty of Women                           9616  10078  12325
# Cruelty by Husband or his Relatives                 47465  48547  50703
# Importation of Girls                                  113     72     46
#
# Year                                                 2004   2005   2006  \
# Rape                                                18233  18359  19348
# Kidnapping and Abduction                            15578  15750  17414
# Dowry Deaths                                         7026   6787   7618
# Assault on women with intent to outrage her mod...  34567  34175  36617
# Insult to modesty of Women                          10001   9984   9966
# Cruelty by Husband or his Relatives                 58121  58319  63128
# Importation of Girls                                   89    149     67
#
# Year                                                 2007   2008   2009  \
# Rape                                                20737  21467  21397
# Kidnapping and Abduction                            20416  22939  25741
# Dowry Deaths                                         8093   8172   8383
# Assault on women with intent to outrage her mod...  38734  40413  38711
# Insult to modesty of Women                          10950  12214  11009
# Cruelty by Husband or his Relatives                 75930  81344  89546
# Importation of Girls                                   61     67     48
#
# Year                                                 2010   2011    2012  \
# Rape                                                22172  24206   24923
# Kidnapping and Abduction                            29795  35565   38262
# Dowry Deaths                                         8391   8618    8233
# Assault on women with intent to outrage her mod...  40613  42968   45351
# Insult to modesty of Women                           9961   8570    9173
# Cruelty by Husband or his Relatives                 94041  99135  106527
# Importation of Girls                                   36     80      59
#
# Year                                                  2013
# Rape                                                 32278
# Kidnapping and Abduction                             49380
# Dowry Deaths                                          7605
# Assault on women with intent to outrage her mod...   67602
# Insult to modesty of Women                           12267
# Cruelty by Husband or his Relatives                 112202
# Importation of Girls                                    31

# %% [markdown]
# ## State / UT wise Analysis of Crime

# %%
plt.figure(figsize=(17,7))
df.groupby("STATE/UT")["Total"].sum().sort_values(ascending=False).plot.bar()
# Out:
# <AxesSubplot:xlabel='STATE/UT'>

# %%
crimes=['Rape','Kidnapping and Abduction','Dowry Deaths',
        'Assault on women with intent to outrage her modesty',
        'Insult to modesty of Women','Cruelty by Husband or his Relatives',
        'Importation of Girls']

df_state=pd.DataFrame()
for i in crimes:
    df_state_crimes=df.groupby(['STATE/UT'])[i].sum()
    df_state[i]=df_state_crimes
df_state["Total"]=df_state.sum(axis=1)
df_state=df_state.sort_values(by="Total",ascending=False)
df_state.reset_index()
df_state
# Out:
#                     Rape  Kidnapping and Abduction  Dowry Deaths  \
# STATE/UT
# andhra pradesh     14993                     16449          6687
# uttar pradesh      21791                     56286         25870
# west bengal        22239                     25070          5565
# madhya pradesh     40265                     12032          9773
# rajasthan          18798                     28360          5451
# maharashtra        20912                     12620          4536
# assam              18001                     26947          1445
# kerala              8602                      2079           321
# gujarat             4908                     15026           527
# bihar              13909                     23502         14519
# odisha             13148                     10270          4925
# karnataka           6148                      6651          3186
# tamil nadu          7875                     13952          2435
# haryana             7379                      8079          3390
# delhi               8060                     19259          1726
# chhattisgarh       13128                      4472          1244
# jharkhand          10302                      6176          3590
# punjab              6344                      6370          1668
# jammu & kashmir     3159                      9735           139
# tripura             2254                       983           338
# uttarakhand         1585                      2926           937
# himachal pradesh    2052                      1830            55
# chandigarh           326                       708            43
# manipur              459                      1182             2
# meghalaya           1192                       296            17
# arunachal pradesh    554                       616             2
# mizoram              915                        12             4
# goa                  436                       234            19
# puducherry            94                       146            27
# a & n islands        136                        89             7
# sikkim               238                        78             2
# nagaland             250                        81             1
# d & n haveli          61                       105             1
# daman & diu           28                        21             3
# lakshadweep            9                         1             0
#
#                    Assault on women with intent to outrage her modesty  \
# STATE/UT
# andhra pradesh                                                 58557
# uttar pradesh                                                  36306
# west bengal                                                    27189
# madhya pradesh                                                 87823
# rajasthan                                                      35434
# maharashtra                                                    46807
# assam                                                          15858
# kerala                                                         35463
# gujarat                                                        10166
# bihar                                                           7733
# odisha                                                         34321
# karnataka                                                      27438
# tamil nadu                                                     20592
# haryana                                                         6865
# delhi                                                          11049
# chhattisgarh                                                   21256
# jharkhand                                                       4498
# punjab                                                          5089
# jammu & kashmir                                                12877
# tripura                                                         3162
# uttarakhand                                                     1812
# himachal pradesh                                                4089
# chandigarh                                                       457
# manipur                                                          563
# meghalaya                                                        625
# arunachal pradesh                                                844
# mizoram                                                          897
# goa                                                              490
# puducherry                                                       625
# a & n islands                                                    259
# sikkim                                                           259
# nagaland                                                         114
# d & n haveli                                                      51
# daman & diu                                                       17
# lakshadweep                                                        6
#
#                    Insult to modesty of Women  \
# STATE/UT
# andhra pradesh                          40660
# uttar pradesh                           26508
# west bengal                              2120
# madhya pradesh                          10036
# rajasthan                                 379
# maharashtra                             14634
# assam                                     126
# kerala                                   3672
# gujarat                                  1430
# bihar                                     274
# odisha                                   3337
# karnataka                                 967
# tamil nadu                              10353
# haryana                                  8780
# delhi                                    2603
# chhattisgarh                             1898
# jharkhand                                 264
# punjab                                    829
# jammu & kashmir                          4336
# tripura                                    45
# uttarakhand                              1555
# himachal pradesh                          550
# chandigarh                                169
# manipur                                     3
# meghalaya                                   8
# arunachal pradesh                          20
# mizoram                                     6
# goa                                       177
# puducherry                                292
# a & n islands                              51
# sikkim                                     14
# nagaland                                   11
# d & n haveli                                5
# daman & diu                                 2
# lakshadweep                                 0
#
#                    Cruelty by Husband or his Relatives  Importation of Girls  \
# STATE/UT
# andhra pradesh                                  133096                    17
# uttar pradesh                                    85832                     3
# west bengal                                     145795                   123
# madhya pradesh                                   44844                    67
# rajasthan                                       113992                     7
# maharashtra                                      87971                     2
# assam                                            47653                    10
# kerala                                           50645                     0
# gujarat                                          66843                     0
# bihar                                            29782                   443
# odisha                                           21240                    18
# karnataka                                        33202                    47
# tamil nadu                                       20657                    15
# haryana                                          30729                     2
# delhi                                            18244                     1
# chhattisgarh                                     10712                     6
# jharkhand                                        10333                   146
# punjab                                           13723                     2
# jammu & kashmir                                   2203                     0
# tripura                                           7290                     0
# uttarakhand                                       4463                     1
# himachal pradesh                                  3572                     0
# chandigarh                                         899                     0
# manipur                                            248                     0
# meghalaya                                          187                     4
# arunachal pradesh                                  175                     0
# mizoram                                             59                     3
# goa                                                231                     0
# puducherry                                         113                     0
# a & n islands                                      130                     0
# sikkim                                              49                     0
# nagaland                                            13                     1
# d & n haveli                                        39                     0
# daman & diu                                         37                     0
# lakshadweep                                          7                     0
#
#                     Total
# STATE/UT
# andhra pradesh     270459
# uttar pradesh      252596
# west bengal        228101
# madhya pradesh     204840
# rajasthan          202421
# maharashtra        187482
# assam              110040
# kerala             100782
# gujarat             98900
# bihar               90162
# odisha              87259
# karnataka           77639
# tamil nadu          75879
# haryana             65224
# delhi               60942
# chhattisgarh        52716
# jharkhand           35309
# punjab              34025
# jammu & kashmir     32449
# tripura             14072
# uttarakhand         13279
# himachal pradesh    12148
# chandigarh           2602
# manipur              2457
# meghalaya            2329
# arunachal pradesh    2211
# mizoram              1896
# goa                  1587
# puducherry           1297
# a & n islands         672
# sikkim                640
# nagaland              471
# d & n haveli          262
# daman & diu           108
# lakshadweep            23

# %% [markdown]
# ### Top 3 States with Higher Number of Crimes

# %%
df_state.head(3)
# Out:
#                  Rape  Kidnapping and Abduction  Dowry Deaths  \
# STATE/UT
# andhra pradesh  14993                     16449          6687
# uttar pradesh   21791                     56286         25870
# west bengal     22239                     25070          5565
#
#                 Assault on women with intent to outrage her modesty  \
# STATE/UT
# andhra pradesh                                              58557
# uttar pradesh                                               36306
# west bengal                                                 27189
#
#                 Insult to modesty of Women  \
# STATE/UT
# andhra pradesh                       40660
# uttar pradesh                        26508
# west bengal                           2120
#
#                 Cruelty by Husband or his Relatives  Importation of Girls  \
# STATE/UT
# andhra pradesh                               133096                    17
# uttar pradesh                                 85832                     3
# west bengal                                  145795                   123
#
#                  Total
# STATE/UT
# andhra pradesh  270459
# uttar pradesh   252596
# west bengal     228101

# %% [markdown]
# ### 3 States with lower Number of Crimes

# %%
df_state.tail(3)
# Out:
#               Rape  Kidnapping and Abduction  Dowry Deaths  \
# STATE/UT
# d & n haveli    61                       105             1
# daman & diu     28                        21             3
# lakshadweep      9                         1             0
#
#               Assault on women with intent to outrage her modesty  \
# STATE/UT
# d & n haveli                                                 51
# daman & diu                                                  17
# lakshadweep                                                   6
#
#               Insult to modesty of Women  Cruelty by Husband or his Relatives  \
# STATE/UT
# d & n haveli                           5                                   39
# daman & diu                            2                                   37
# lakshadweep                            0                                    7
#
#               Importation of Girls  Total
# STATE/UT
# d & n haveli                     0    262
# daman & diu                      0    108
# lakshadweep                      0     23

# %% [markdown]
# ### Top 5 States having higher Rape Cases

# %%
top_rape_by_state=df_state.sort_values(by="Rape",ascending=False)
top_3rape=top_rape_by_state.iloc[:,0:1].head(5)
plt.figure(figsize=(10,5))
plt.pie(top_3rape.Rape,labels=top_3rape.index,colors=['lightcoral','skyblue','lightgreen',"royalblue","green"],startangle=45,autopct='%1.2f%%',textprops={'fontsize': 18},shadow=True,explode=[0.01,0.01,0.01,0.01,0.01])
plt.title("Top 5 States by No. of Cases on Rape",fontdict={'fontsize' : 20})
plt.tight_layout()

# %% [markdown]
# ### Top 5 States having higher Kidnapping and Abduction

# %%
top_kidabd_by_state=df_state.sort_values(by="Kidnapping and Abduction",ascending=False)
top_3kidabd=top_kidabd_by_state.iloc[:,1:2].head(5)
plt.figure(figsize=(10,5))
plt.pie(top_3kidabd["Kidnapping and Abduction"],labels=top_3rape.index,colors=['lightcoral','skyblue','lightgreen',"royalblue","green"],startangle=45,autopct='%1.2f%%',textprops={'fontsize': 18},shadow=True,explode=[0.01,0.01,0.01,0.01,0.01])
plt.title("Top 5 States by No. of Cases on Kidnapping and Abduction",fontdict={'fontsize' : 20})
plt.tight_layout()

# %% [markdown]
# ### **Top 5 States having higher Dowry Death's**

# %%
top_dow_by_state=df_state.sort_values(by="Dowry Deaths",ascending=False)
top_3dow=top_dow_by_state.iloc[:,2:3].head(5)
plt.figure(figsize=(10,5))
plt.pie(top_3dow["Dowry Deaths"],labels=top_3rape.index,colors=['lightcoral','skyblue','lightgreen',"royalblue","green"],startangle=45,autopct='%1.2f%%',textprops={'fontsize': 18},shadow=True,explode=[0.01,0.01,0.01,0.01,0.01])
plt.title("Top 5 States by No. of Cases on Dowry Deaths",fontdict={'fontsize' : 20})
plt.tight_layout()

# %% [markdown]
# ### **Top 5 States having higher Assault on women with intent to outrage her modesty**

# %%
top_ass_by_state=df_state.sort_values(by="Assault on women with intent to outrage her modesty",ascending=False)
top_3ass=top_ass_by_state.iloc[:,3:4].head(5)
plt.figure(figsize=(10,5))
plt.pie(top_3ass["Assault on women with intent to outrage her modesty"],labels=top_3rape.index,colors=['lightcoral','skyblue','lightgreen',"royalblue","green"],startangle=45,autopct='%1.2f%%',textprops={'fontsize': 18},shadow=True,explode=[0.01,0.01,0.01,0.01,0.01])
plt.title("Top 5 States by No. of Cases on Assault on women with intent to outrage her modesty",fontdict={'fontsize' : 20})
plt.tight_layout()

# %% [markdown]
# ###**Top 5 States having higher Assault on women with intent to outrage her modesty**

# %%
top_ass_by_state=df_state.sort_values(by="Assault on women with intent to outrage her modesty",ascending=False)
top_3ass=top_ass_by_state.iloc[:,3:4].head(5)
plt.figure(figsize=(10,5))
plt.pie(top_3ass["Assault on women with intent to outrage her modesty"],labels=top_3rape.index,colors=['lightcoral','skyblue','lightgreen',"royalblue","green"],startangle=45,autopct='%1.2f%%',textprops={'fontsize': 18},shadow=True,explode=[0.01,0.01,0.01,0.01,0.01])
plt.title("Top 5 States by No. of Cases on Assault on women with intent to outrage her modesty",fontdict={'fontsize' : 20})
plt.tight_layout()

# %% [markdown]
# ### **Top 5 States having higher Insult to modesty of Women**

# %%
top_mod_by_state=df_state.sort_values(by="Insult to modesty of Women",ascending=False)
top_3mod=top_mod_by_state.iloc[:,4:5].head(5)
plt.figure(figsize=(10,5))
plt.pie(top_3mod["Insult to modesty of Women"],labels=top_3rape.index,colors=['lightcoral','skyblue','lightgreen',"royalblue","green"],startangle=45,autopct='%1.2f%%',textprops={'fontsize': 14},shadow=True,explode=[0.012,0.012,0.012,0.012,0.012])
plt.title("Top 5 States by No. of Cases on Insult to modesty of Women",fontdict={'fontsize' : 22})
plt.tight_layout()

# %% [markdown]
# ###**Top 5 States having higher cases on Cruelty by Husband or his Relatives**

# %%
top_cr_by_state=df_state.sort_values(by="Cruelty by Husband or his Relatives",ascending=False)
top_3cr=top_cr_by_state.iloc[:,5:6].head(5)
plt.figure(figsize=(10,5))
plt.pie(top_3cr["Cruelty by Husband or his Relatives"],labels=top_3rape.index,colors=['lightcoral','skyblue','lightgreen',"royalblue","green"],startangle=45,autopct='%1.2f%%',textprops={'fontsize': 14},shadow=True,explode=[0.012,0.012,0.012,0.012,0.012])
plt.title("Top 5 States by No. of Cases on Cruelty by Husband or his Relatives",fontdict={'fontsize' : 22})
plt.tight_layout()

# %% [markdown]
# ###**Top 5 States having higher cases on Importation of Girls**

# %%
top_imp_by_state=df_state.sort_values(by="Importation of Girls",ascending=False)
top_3imp=top_imp_by_state.iloc[:,6:7].head(5)
plt.figure(figsize=(10,5))
plt.pie(top_3imp["Importation of Girls"],labels=top_3rape.index,colors=['lightcoral','skyblue','lightgreen',"royalblue","green"],startangle=45,autopct='%1.2f%%',textprops={'fontsize': 14},shadow=True,explode=[0.012,0.012,0.012,0.012,0.012])
plt.title("Top 5 States by No. of Cases on Importation of Girls",fontdict={'fontsize' : 22})
plt.tight_layout()

# %% [markdown]
# ## Analysis of Top 5 States

# %% [markdown]
# ### **1. Uttar Pradesh**

# %%
df_up=df_state.loc[df_state.index=="uttar pradesh"]
dfupT=df_up.T.drop("Total")
dfupT
# Out:
# STATE/UT                                            uttar pradesh
# Rape                                                        21791
# Kidnapping and Abduction                                    56286
# Dowry Deaths                                                25870
# Assault on women with intent to outrage her mod...          36306
# Insult to modesty of Women                                  26508
# Cruelty by Husband or his Relatives                         85832
# Importation of Girls                                            3

# %% [markdown]
# #### **Percentage Distribution of Crimes in Uttar Pradesh from 2001 to 2014**

# %%
plt.figure(figsize=(12,5)).patch.set_facecolor("#F1EDD7FF")
plt.pie(dfupT["uttar pradesh"].sort_values(ascending=False),labels=dfupT.index,autopct='%1.2f%%')
plt.tight_layout()

# %%
plt.figure(figsize=(13,7))
dfupT.groupby(dfupT.index)["uttar pradesh"].sum().sort_values(ascending=False).plot.bar()
plt.tight_layout()

# %% [markdown]
# #### **Year Wise Distribution of Crimes in Uttar Pradesh**

# %%
crime_up=['Rape','Kidnapping and Abduction','Dowry Deaths',
        'Assault on women with intent to outrage her modesty',
        'Insult to modesty of Women','Cruelty by Husband or his Relatives',
        'Importation of Girls',"Total"]

df_up_year=df.loc[df['STATE/UT']=='uttar pradesh']

df1_up_yearwise=pd.DataFrame()
for i in crime_up:
    df_crimes_up=df_up_year.groupby(['Year'])[i].sum()
    df1_up_yearwise[i]=df_crimes_up
df1_up_yearwise
# Out:
#       Rape  Kidnapping and Abduction  Dowry Deaths  \
# Year
# 2001  1933                      2848          2146
# 2002  1415                      2298          1893
# 2003   911                      1499          1322
# 2004  1397                      2324          1708
# 2005  1217                      2256          1564
# 2006  1314                      2551          1798
# 2007  1648                      3363          2076
# 2008  1871                      4439          2237
# 2009  1759                      5078          2232
# 2010  1563                      5468          2217
# 2011  2042                      7525          2322
# 2012  1963                      7910          2244
# 2013  2758                      8727          2111
#
#       Assault on women with intent to outrage her modesty  \
# Year
# 2001                                               2817
# 2002                                               2145
# 2003                                               1098
# 2004                                               1900
# 2005                                               1835
# 2006                                               2096
# 2007                                               2522
# 2008                                               2955
# 2009                                               2782
# 2010                                               2793
# 2011                                               3455
# 2012                                               3247
# 2013                                               6661
#
#       Insult to modesty of Women  Cruelty by Husband or his Relatives  \
# Year
# 2001                        2549                                 7255
# 2002                        1887                                 5679
# 2003                        4970                                 2626
# 2004                        2682                                 4950
# 2005                        2881                                 4505
# 2006                        2714                                 5204
# 2007                        2882                                 7650
# 2008                        3374                                 8312
# 2009                        2524                                 8566
# 2010                          11                                 7978
# 2011                           3                                 7121
# 2012                           8                                 7661
# 2013                          23                                 8325
#
#       Importation of Girls  Total
# Year
# 2001                     0  19548
# 2002                     0  15317
# 2003                     0  12426
# 2004                     3  14964
# 2005                     0  14258
# 2006                     0  15677
# 2007                     0  20141
# 2008                     0  23188
# 2009                     0  22941
# 2010                     0  20030
# 2011                     0  22468
# 2012                     0  23033
# 2013                     0  28605

# %%
plt.figure(figsize=(10,5))
sns.barplot(data=df1_up_yearwise,x=df1_up_yearwise.index,y='Total',color="lightblue")
plt.tight_layout()

# %%
plt.figure(figsize=(13,6)).patch.set_facecolor("#F1EDD7FF")
plt.pie(df1_up_yearwise["Total"],labels=df1_up_yearwise.index,autopct='%1.2f%%',counterclock=False)
plt.tight_layout()

# %% [markdown]
# #### **Timeline Analysis of Different Categories of Crime at Different Period of Time**

# %%
plt.figure(figsize=(17,7)).patch.set_facecolor("#F1EDD7FF")
sns.lineplot(data=df1_up_yearwise,palette='gnuplot_r',linestyle="dashed")
plt.tight_layout()

# %% [markdown]
# ### **2. Madhya Pradesh**

# %%
df_ap=df_state.loc[df_state.index=="madhya pradesh"]
dfapT=df_ap.T.drop("Total")
dfapT
# Out:
# STATE/UT                                            madhya pradesh
# Rape                                                         40265
# Kidnapping and Abduction                                     12032
# Dowry Deaths                                                  9773
# Assault on women with intent to outrage her mod...           87823
# Insult to modesty of Women                                   10036
# Cruelty by Husband or his Relatives                          44844
# Importation of Girls                                            67

# %% [markdown]
# #### **Percentage Distribution of Crimes in from 2001 to 2014**

# %%
plt.figure(figsize=(13,6)).patch.set_facecolor("#F1EDD7FF")
plt.pie(dfapT["madhya pradesh"],labels=dfapT.index,autopct="%1.2f%%")
plt.tight_layout()

# %%
plt.figure(figsize=(12,6)).patch.set_facecolor("#F1EDD7FF")
sns.barplot(data=dfapT,x=dfapT.index,y=dfapT["madhya pradesh"],color="lightblue")
plt.xticks(rotation=90)
plt.tight_layout()

# %% [markdown]
# #### **Year Wise Distribution of Crimes**

# %%
crime_ap=['Rape','Kidnapping and Abduction','Dowry Deaths',
        'Assault on women with intent to outrage her modesty',
        'Insult to modesty of Women','Cruelty by Husband or his Relatives',
        'Importation of Girls',"Total"]

df_ap_year=df.loc[df['STATE/UT']=='madhya pradesh']

df1_ap_yearwise=pd.DataFrame()
for i in crime_ap:
    df_crimes_ap=df_ap_year.groupby(['Year'])[i].sum()
    df1_ap_yearwise[i]=df_crimes_ap
df1_ap_yearwise
# Out:
#       Rape  Kidnapping and Abduction  Dowry Deaths  \
# Year
# 2001  2807                       658           590
# 2002  2891                       639           674
# 2003  2738                       608           648
# 2004  2875                       584           751
# 2005  2921                       604           739
# 2006  2900                       617           764
# 2007  3010                       701           742
# 2008  2937                       736           805
# 2009  2998                       841           858
# 2010  3135                      1030           892
# 2011  3406                      1088           811
# 2012  3425                      1127           743
# 2013  4222                      2799           756
#
#       Assault on women with intent to outrage her modesty  \
# Year
# 2001                                               6959
# 2002                                               7118
# 2003                                               6848
# 2004                                               6690
# 2005                                               6426
# 2006                                               6243
# 2007                                               6772
# 2008                                               6445
# 2009                                               6307
# 2010                                               6646
# 2011                                               6665
# 2012                                               6655
# 2013                                               8049
#
#       Insult to modesty of Women  Cruelty by Husband or his Relatives  \
# Year
# 2001                         749                                 2531
# 2002                         783                                 3117
# 2003                         705                                 2938
# 2004                         804                                 3436
# 2005                         792                                 2989
# 2006                         762                                 2989
# 2007                         780                                 3294
# 2008                         758                                 3185
# 2009                         728                                 3983
# 2010                         918                                 3756
# 2011                         762                                 3732
# 2012                         774                                 3988
# 2013                         721                                 4906
#
#       Importation of Girls  Total
# Year
# 2001                     0  14294
# 2002                     0  15222
# 2003                     0  14485
# 2004                     0  15140
# 2005                     3  14474
# 2006                     0  14275
# 2007                     0  15299
# 2008                     0  14866
# 2009                     1  15716
# 2010                     5  16382
# 2011                    45  16509
# 2012                     6  16718
# 2013                     7  21460

# %%
plt.figure(figsize=(10,5)).patch.set_facecolor("#F1EDD7FF")
plt.axes().set_facecolor("#F1EDD7FF")
sns.barplot(data=df1_ap_yearwise,x=df1_ap_yearwise.index,y='Total',color="lightblue")
plt.tight_layout()

# %%
plt.figure(figsize=(13,6)).patch.set_facecolor("#F1EDD7FF")
plt.pie(df1_ap_yearwise["Total"],labels=df1_ap_yearwise.index,autopct='%1.2f%%',counterclock=False)
plt.tight_layout()

# %% [markdown]
# #### **Timeline Analysis of Different Categories of Crime at Different Period of Time**

# %%
plt.figure(figsize=(17,7)).patch.set_facecolor("#F1EDD7FF")
sns.lineplot(data=df1_ap_yearwise,palette='gnuplot_r',linestyle="dashed")
plt.tight_layout()

# %% [markdown]
# ### **3. West Bengal**

# %%
df_wb=df_state.loc[df_state.index=="west bengal"]
dfwbT=df_wb.T.drop("Total")
dfwbT
# Out:
# STATE/UT                                            west bengal
# Rape                                                      22239
# Kidnapping and Abduction                                  25070
# Dowry Deaths                                               5565
# Assault on women with intent to outrage her mod...        27189
# Insult to modesty of Women                                 2120
# Cruelty by Husband or his Relatives                      145795
# Importation of Girls                                        123

# %% [markdown]
# #### **Percentage Distribution of Crimes in from 2001 to 2014**

# %%
plt.figure(figsize=(13,6)).patch.set_facecolor("#F1EDD7FF")
plt.pie(dfwbT["west bengal"],labels=dfwbT.index,autopct="%1.2f%%")
plt.tight_layout()

# %%
plt.figure(figsize=(13,7))
dfwbT.groupby(dfwbT.index)["west bengal"].sum().sort_values(ascending=False).plot.bar()
plt.tight_layout()

# %% [markdown]
# #### **Year Wise Distribution of Crimes**

# %%
crime_wb=['Rape','Kidnapping and Abduction','Dowry Deaths',
        'Assault on women with intent to outrage her modesty',
        'Insult to modesty of Women','Cruelty by Husband or his Relatives',
        'Importation of Girls',"Total"]

df_wb_year=df.loc[df['STATE/UT']=='west bengal']

df1_wb_yearwise=pd.DataFrame()
for i in crime_wb:
    df_crimes_wb=df_wb_year.groupby(['Year'])[i].sum()
    df1_wb_yearwise[i]=df_crimes_wb
df1_wb_yearwise
# Out:
#       Rape  Kidnapping and Abduction  Dowry Deaths  \
# Year
# 2001   662                       643           217
# 2002   759                       694           273
# 2003  1002                       801           329
# 2004  1475                      1018           396
# 2005  1686                      1039           446
# 2006  1731                      1199           445
# 2007  2106                      1590           451
# 2008  2263                      1907           451
# 2009  2336                      2187           506
# 2010  2311                      2764           507
# 2011  2363                      3711           510
# 2012  2046                      4168           593
# 2013  1499                      3349           441
#
#       Assault on women with intent to outrage her modesty  \
# Year
# 2001                                                900
# 2002                                                964
# 2003                                               1186
# 2004                                               1566
# 2005                                               1572
# 2006                                               1837
# 2007                                               2281
# 2008                                               2396
# 2009                                               1942
# 2010                                               2465
# 2011                                               2363
# 2012                                               3345
# 2013                                               4372
#
#       Insult to modesty of Women  Cruelty by Husband or his Relatives  \
# Year
# 2001                          48                                 3379
# 2002                          34                                 4069
# 2003                          71                                 4948
# 2004                          64                                 6334
# 2005                          54                                 6936
# 2006                          63                                 7414
# 2007                          99                                 9900
# 2008                          94                                13663
# 2009                         108                                16112
# 2010                         163                                17796
# 2011                         200                                19772
# 2012                         556                                19865
# 2013                         566                                15607
#
#       Importation of Girls  Total
# Year
# 2001                     3   5852
# 2002                     1   6794
# 2003                     1   8338
# 2004                    12  10865
# 2005                    61  11794
# 2006                     1  12690
# 2007                     5  16432
# 2008                     5  20779
# 2009                     5  23196
# 2010                     8  26014
# 2011                     0  28919
# 2012                    12  30585
# 2013                     9  25843

# %%
plt.figure(figsize=(10,5)).patch.set_facecolor("#F1EDD7FF")
plt.axes().set_facecolor("#F1EDD7FF")
sns.barplot(data=df1_wb_yearwise,x=df1_wb_yearwise.index,y='Total',color="lightblue")
plt.tight_layout()

# %%
plt.figure(figsize=(13,6)).patch.set_facecolor("#F1EDD7FF")
plt.pie(df1_wb_yearwise["Total"],labels=df1_wb_yearwise.index,autopct='%1.2f%%',counterclock=False)
plt.tight_layout()

# %% [markdown]
# #### **Timeline Analysis of Different Categories of Crime at Different Period of Time**

# %%
plt.figure(figsize=(17,7)).patch.set_facecolor("#F1EDD7FF")
sns.lineplot(data=df1_wb_yearwise,palette='gnuplot_r',linestyle="dashed")
plt.tight_layout()

# %% [markdown]
# ```
# # This is formatted as code
# ```
#
# ### **2. Maharashtra**

# %%
df_mh=df_state.loc[df_state.index=="maharashtra"]
dfmhT=df_mh.T.drop("Total")
dfmhT
# Out:
# STATE/UT                                            maharashtra
# Rape                                                      20912
# Kidnapping and Abduction                                  12620
# Dowry Deaths                                               4536
# Assault on women with intent to outrage her mod...        46807
# Insult to modesty of Women                                14634
# Cruelty by Husband or his Relatives                       87971
# Importation of Girls                                          2

# %% [markdown]
# #### **Percentage Distribution of Crimes in from 2001 to 2014**

# %%
plt.figure(figsize=(13,6)).patch.set_facecolor("#F1EDD7FF")
plt.pie(dfmhT["maharashtra"],labels=dfmhT.index,autopct="%1.2f%%")
plt.tight_layout()

# %%
plt.figure(figsize=(12,6)).patch.set_facecolor("#F1EDD7FF")
sns.barplot(data=dfapT,x=dfmhT.index,y=dfmhT["maharashtra"],color="lightblue")
plt.xticks(rotation=90)
plt.tight_layout()

# %% [markdown]
# #### **Year Wise Distribution of Crimes**

# %%
crime_mh=['Rape','Kidnapping and Abduction','Dowry Deaths',
        'Assault on women with intent to outrage her modesty',
        'Insult to modesty of Women','Cruelty by Husband or his Relatives',
        'Importation of Girls',"Total"]

df_mh_year=df.loc[df['STATE/UT']=='maharashtra']

df1_mh_yearwise=pd.DataFrame()
for i in crime_mh:
    df_crimes_mh=df_mh_year.groupby(['Year'])[i].sum()
    df1_mh_yearwise[i]=df_crimes_mh
df1_mh_yearwise
# Out:
#       Rape  Kidnapping and Abduction  Dowry Deaths  \
# Year
# 2001  1279                       588           298
# 2002  1352                       650           303
# 2003  1268                       626           368
# 2004  1388                       787           314
# 2005  1545                       851           341
# 2006  1500                       921           387
# 2007  1451                       967           436
# 2008  1558                       998           390
# 2009  1483                       926           341
# 2010  1599                      1124           393
# 2011  1701                      1252           339
# 2012  1839                      1140           329
# 2013  2949                      1790           297
#
#       Assault on women with intent to outrage her modesty  \
# Year
# 2001                                               2780
# 2002                                               2686
# 2003                                               2661
# 2004                                               2831
# 2005                                               3228
# 2006                                               3479
# 2007                                               3306
# 2008                                               3619
# 2009                                               3196
# 2010                                               3661
# 2011                                               3794
# 2012                                               3935
# 2013                                               7631
#
#       Insult to modesty of Women  Cruelty by Husband or his Relatives  \
# Year
# 2001                        1094                                 6035
# 2002                         769                                 5353
# 2003                         682                                 5452
# 2004                         862                                 5646
# 2005                         919                                 6233
# 2006                         984                                 6738
# 2007                        1039                                 7356
# 2008                        1091                                 7829
# 2009                        1099                                 7681
# 2010                        1180                                 7434
# 2011                        1071                                 7136
# 2012                        1294                                 7415
# 2013                        2550                                 7663
#
#       Importation of Girls  Total
# Year
# 2001                     1  12075
# 2002                     0  11113
# 2003                     0  11057
# 2004                     0  11828
# 2005                     0  13117
# 2006                     1  14010
# 2007                     0  14555
# 2008                     0  15485
# 2009                     0  14726
# 2010                     0  15391
# 2011                     0  15293
# 2012                     0  15952
# 2013                     0  22880

# %%
plt.figure(figsize=(10,5)).patch.set_facecolor("#F1EDD7FF")
plt.axes().set_facecolor("#F1EDD7FF")
sns.barplot(data=df1_mh_yearwise,x=df1_mh_yearwise.index,y='Total',color="lightblue")
plt.tight_layout()

# %%
plt.figure(figsize=(13,6)).patch.set_facecolor("#F1EDD7FF")
plt.pie(df1_mh_yearwise["Total"],labels=df1_mh_yearwise.index,autopct='%1.2f%%',counterclock=False)
plt.tight_layout()

# %% [markdown]
# #### **Timeline Analysis of Different Categories of Crime at Different Period of Time**

# %%
plt.figure(figsize=(17,7)).patch.set_facecolor("#F1EDD7FF")
sns.lineplot(data=df1_mh_yearwise,palette='gnuplot_r',linestyle="dashed")
plt.tight_layout()
